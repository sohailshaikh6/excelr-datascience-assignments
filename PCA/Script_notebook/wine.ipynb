# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
import seaborn as sns
from sklearn.decomposition import PCA
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ## __1 - Business Problem__
# ___Perform Principal component analysis and perform clustering using first
# 3 principal component scores (both heirarchial and k mean clustering(scree plot or elbow curve) and obtain
# optimum number of clusters and check whether we have obtained same number of clusters with the original data___

# %% [markdown]
# ## __2 - Data collection and description__

# %%
df = pd.read_csv("C:/Users/SohailShaikh/Downloads/wine.csv")

# %%
df1 = df.iloc[:, 1:]

# %%
df1.head()
# Out:
#    Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
df1.describe()
# Out:
#           Alcohol       Malic         Ash  Alcalinity   Magnesium     Phenols  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean    13.000618    2.336348    2.366517   19.494944   99.741573    2.295112
# std      0.811827    1.117146    0.274344    3.339564   14.282484    0.625851
# min     11.030000    0.740000    1.360000   10.600000   70.000000    0.980000
# 25%     12.362500    1.602500    2.210000   17.200000   88.000000    1.742500
# 50%     13.050000    1.865000    2.360000   19.500000   98.000000    2.355000
# 75%     13.677500    3.082500    2.557500   21.500000  107.000000    2.800000
# max     14.830000    5.800000    3.230000   30.000000  162.000000    3.880000
#
#        Flavanoids  Nonflavanoids  Proanthocyanins       Color         Hue  \
# count  178.000000     178.000000       178.000000  178.000000  178.000000
# mean     2.029270       0.361854         1.590899    5.058090    0.957449
# std      0.998859       0.124453         0.572359    2.318286    0.228572
# min      0.340000       0.130000         0.410000    1.280000    0.480000
# 25%      1.205000       0.270000         1.250000    3.220000    0.782500
# 50%      2.135000       0.340000         1.555000    4.690000    0.965000
# 75%      2.875000       0.437500         1.950000    6.200000    1.120000
# max      5.080000       0.660000         3.580000   13.000000    1.710000
#
#          Dilution      Proline
# count  178.000000   178.000000
# mean     2.611685   746.893258
# std      0.709990   314.907474
# min      1.270000   278.000000
# 25%      1.937500   500.500000
# 50%      2.780000   673.500000
# 75%      3.170000   985.000000
# max      4.000000  1680.000000

# %% [markdown]
# ## __3 - Finding correlation between the variables in the data__

# %%
cor = df1.corr()

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col1 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col2 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col3 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col4 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col5 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col6 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col7 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col8 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col9 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col10 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col11 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row0_col12 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col2 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col3 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col4 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col5 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col6 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col7 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col8 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col9 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col11 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row1_col12 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col0 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col1 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col3 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col4 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col5 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col6 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col7 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col8 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col9 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col10 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col11 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row2_col12 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col1 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col2 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col4 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col5 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col7 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col8 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col9 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col10 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col11 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row3_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row4_col0 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row4_col1 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row4_col2 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row4_col3 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row4_col5 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row4_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_2cd76590_9837_11ea_8e7c_f8c433693df2row4_col7 {
#             background-color:  #7597f6;
#             color:

# %% [markdown]
# ### There are some quite correlation between variables. For example the correlation between flavanoids and dilution is pretty high (78%). Thus we can remove that variable from our dataset. However this method is long and tedious. Hence we PCA method for Dimensionality Reduction

# %% [markdown]
# ## __4 - Dimensionality Reduction with PCA__

# %%
df_norm = StandardScaler().fit_transform(df1) # normalizing the data

# %%
pca = PCA(n_components=13)

# %%
principalComponents = pca.fit_transform(df_norm)

# %%
PC = range(1, pca.n_components_+1)
plt.bar(PC, pca.explained_variance_ratio_, color='blue')
plt.xlabel('Principal Components')
plt.ylabel('Variance %')
plt.xticks(PC)
# Out:
# ([<matplotlib.axis.XTick at 0x219093a1e08>,
#   <matplotlib.axis.XTick at 0x219093a1dc8>,
#   <matplotlib.axis.XTick at 0x21909342748>,
#   <matplotlib.axis.XTick at 0x21909347788>,
#   <matplotlib.axis.XTick at 0x21909017cc8>,
#   <matplotlib.axis.XTick at 0x21909374408>,
#   <matplotlib.axis.XTick at 0x21908f946c8>,
#   <matplotlib.axis.XTick at 0x21908f94048>,
#   <matplotlib.axis.XTick at 0x21909334048>,
#   <matplotlib.axis.XTick at 0x21908f712c8>,
#   <matplotlib.axis.XTick at 0x21909443088>,
#   <matplotlib.axis.XTick at 0x21909443948>,
#   <matplotlib.axis.XTick at 0x21909447248>],
#  <a list of 13 Text major ticklabel objects>)

# %%
plt.scatter(PCA_components[0], PCA_components[1], alpha=.3, color='blue')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.show()

# %% [markdown]
# ### As shown in the bar graph, the most of varianve is put in the first 2 components. Since there is not much variance present from 3rd component, lets just the first 2 componets in our analysis. The scatter plot given an indication that there may be 3 clusters present

# %% [markdown]
# ## __5 - Finding out the optimal number of clusters__

# %%
PCA_components = pd.DataFrame(principalComponents)

# %%
wcss = []

# %%
for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(PCA_components.iloc[:,:3])
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 15), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### The scree plot levels off at k=3 and let's use it to determine the clusters

# %% [markdown]
# ## __6 - K clusters__

# %%
model = KMeans(n_clusters=3)
model.fit(PCA_components.iloc[:,:2])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels = model.predict(PCA_components.iloc[:,:2])

# %%
plt.scatter(PCA_components[0], PCA_components[1], c=labels)
plt.show()

# %% [markdown]
# ## __7 - H clusters__

# %%
dendrogram = sch.dendrogram(sch.linkage(PCA_components.iloc[:,:2], method='ward'))

# %%
model2 = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')

# %%
h_cluster = model2.fit(PCA_components.iloc[:,:2])

# %%
labels2 = model2.labels_

# %%
X = PCA_components.iloc[:,:1]
Y = PCA_components.iloc[:,1:2]

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(X, Y, c=labels2)

# %% [markdown]
# ## __8 - Conclusion__

# %% [markdown]
# Using PCA we reduced the variables to only 2 from 13
# and use clustering classification, we can safely assume that there exists 3 cluster in the wine data sets
