# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense, Activation,Layer,Lambda
import seaborn as sns
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_decision_regions
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers.normalization import BatchNormalization
from keras import backend
from keras.optimizers import Adam
from sklearn.metrics import r2_score

# %% [markdown]
# ## __1 - Business Problem__
# ___Prepare a model for strength of concrete data using Neural Networks___

# %% [markdown]
# ## __2 - Data collection and description__

# %%
df = pd.read_csv("C:/Users/SohailShaikh/OneDrive - tiqets.com/Tiqets/Adhoc/DS/Neural Netrworks/concrete.csv")

# %%
df1 = df.copy()

# %%
df1
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# 4        18.29
# ...        ...
# 1025     13.29
# 1026     41.30
# 1027     44.28
# 1028     55.06
# 1029     52.61
#
# [1030 rows x 9 columns]

# %%
df1.isnull().sum()
# Out:
# cement          0
# slag            0
# ash             0
# water           0
# superplastic    0
# coarseagg       0
# fineagg         0
# age             0
# strength        0
# dtype: int64

# %%
df1.describe().T
# Out:
#                count        mean         std     min      25%      50%  \
# cement        1030.0  281.167864  104.506364  102.00  192.375  272.900
# slag          1030.0   73.895825   86.279342    0.00    0.000   22.000
# ash           1030.0   54.188350   63.997004    0.00    0.000    0.000
# water         1030.0  181.567282   21.354219  121.80  164.900  185.000
# superplastic  1030.0    6.204660    5.973841    0.00    0.000    6.400
# coarseagg     1030.0  972.918932   77.753954  801.00  932.000  968.000
# fineagg       1030.0  773.580485   80.175980  594.00  730.950  779.500
# age           1030.0   45.662136   63.169912    1.00    7.000   28.000
# strength      1030.0   35.817961   16.705742    2.33   23.710   34.445
#
#                    75%     max
# cement         350.000   540.0
# slag           142.950   359.4
# ash            118.300   200.1
# water          192.000   247.0
# superplastic    10.200    32.2
# coarseagg     1029.400  1145.0
# fineagg        824.000   992.6
# age             56.000   365.0
# strength        46.135    82.6

# %% [markdown]
# ### Outlier Check

# %%
ax = sns.boxplot(df1['strength'])

# %% [markdown]
# ### There are 3 Outlier instances in our data

# %%
plt.rcParams["figure.figsize"] = 9,5

# %%
plt.figure(figsize=(16,5))
print("Skew: {}".format(df1['strength'].skew()))
print("Kurtosis: {}".format(df1['strength'].kurtosis()))
ax = sns.kdeplot(df1['strength'],shade=True,color='g')
plt.xticks([i for i in range(0,100,10)])
plt.show()
# Out:
# Skew: 0.41697728841071807
# Kurtosis: -0.3137248604469969

# %% [markdown]
# ### The Data is positively skewed and has negative kurtosis value
# ### Majority of the cement has maximum strengt between 20 and 60

# %%
num_columns = dfa.select_dtypes(exclude='object').columns.tolist()

# %%
plt.figure(figsize=(18,40))
for i,col in enumerate(num_columns,1):
    plt.subplot(8,4,i)
    sns.kdeplot(df[col],color='g',shade=True)
    plt.subplot(8,4,i+10)
    df[col].plot.box()
plt.tight_layout() 
plt.show()
num_data = df[num_columns]
pd.DataFrame(data=[num_data.skew(),num_data.kurtosis()],index=['skewness','kurtosis'])
# Out:
#             cement      slag       ash     water  superplastic  coarseagg  \
# skewness  0.509481  0.800717  0.537354  0.074628      0.907203  -0.040220
# kurtosis -0.520652 -0.508175 -1.328746  0.122082      1.411269  -0.599016
#
#            fineagg        age  strength
# skewness -0.253010   3.269177  0.416977
# kurtosis -0.102177  12.168989 -0.313725

# %% [markdown]
# ### Finding Correlation

# %%
corr = df1.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)

# %% [markdown]
# ## __3 - Neural Network Model__

# %%
X = df1.iloc[:,0:8]
y = df1.iloc[:,8]

# %%
x_train,x_test,y_train,y_test= train_test_split(X,y, test_size=0.3)

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
def rmse(y_true, y_pred):
	return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# %%
model=Sequential()

# %%
model.add(Dense(64,input_dim=8,activation = 'relu'))
model.add(Dense(32,activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1,activation='linear'))

# %%
opt = Adam(lr=0.0015)

# %%
model.compile(optimizer=opt,loss='mean_squared_error',metrics=[rmse])

# %%
history = model.fit(x_train,y_train,epochs = 35 ,batch_size=32,validation_split=0.1)
# Out:
# Train on 648 samples, validate on 73 samples
# Epoch 1/35
# 648/648 [==============================] - 0s 491us/step - loss: 1485.7129 - rmse: 35.1929 - val_loss: 1673.0959 - val_rmse: 37.5567
# Epoch 2/35
# 648/648 [==============================] - 0s 43us/step - loss: 1414.1777 - rmse: 34.9056 - val_loss: 1642.1119 - val_rmse: 37.3752
# Epoch 3/35
# 648/648 [==============================] - 0s 45us/step - loss: 1354.2817 - rmse: 34.5383 - val_loss: 1600.6872 - val_rmse: 37.1106
# Epoch 4/35
# 648/648 [==============================] - 0s 46us/step - loss: 1294.0050 - rmse: 34.0722 - val_loss: 1548.3468 - val_rmse: 36.7453
# Epoch 5/35
# 648/648 [==============================] - 0s 43us/step - loss: 1230.6623 - rmse: 33.4940 - val_loss: 1486.1445 - val_rmse: 36.2323
# Epoch 6/35
# 648/648 [==============================] - 0s 43us/step - loss: 1163.4803 - rmse: 32.8085 - val_loss: 1406.4453 - val_rmse: 35.4133
# Epoch 7/35
# 648/648 [==============================] - 0s 40us/step - loss: 1095.6775 - rmse: 32.0058 - val_loss: 1326.8431 - val_rmse: 34.5866
# Epoch 8/35
# 648/648 [==============================] - 0s 43us/step - loss: 1028.9379 - rmse: 31.0943 - val_loss: 1252.8164 - val_rmse: 33.5980
# Epoch 9/35
# 648/648 [==============================] - 0s 35us/step - loss: 963.0780 - rmse: 30.0973 - val_loss: 1136.4646 - val_rmse: 32.1145
# Epoch 10/35
# 648/648 [==============================] - 0s 40us/step - loss: 884.4427 - rmse: 28.9948 - val_loss: 1006.5161 - val_rmse: 30.1577
# Epoch 11/35
# 648/648 [==============================] - 0s 42us/step - loss: 811.0642 - rmse: 27.7971 - val_loss: 882.4590 - val_rmse: 28.1411
# Epoch 12/35
# 648/648 [==============================] - 0s 35us/step - loss: 747.7544 - rmse: 26.5227 - val_loss: 747.9433 - val_rmse: 25.8483
# Epoch 13/35
# 648/648 [==============================] - 0s 39us/step - loss: 665.0504 - rmse: 25.1438 - val_loss: 651.1987 - val_rmse: 24.0109
# Epoch 14/35
# 648/648 [==============================] - 0s 39us/step - loss: 594.8133 - rmse: 23.6794 - val_loss: 562.9088 - val_rmse: 22.2204
# Epoch 15/35
# 648/648 [==============================] - 0s 35us/step - loss: 525.8397 - rmse: 22.1482 - val_loss: 457.4448 - val_rmse: 19.9220
# Epoch 16/35
# 648/648 [==============================] - 0s 39us/step - loss: 457.9161 - rmse: 20.5752 - val_loss: 361.0820 - val_rmse: 17.5061
# Epoch 17/35
# 648/648 [==============================] - 0s 36us/step - loss: 391.8282 - rmse: 18.9568 - val_loss: 299.4406 - val_rmse: 15.7345
# Epoch 18/35
# 648/648 [==============================] - 0s 37us/step - loss: 332.1661 - rmse: 17.3606 - val_loss: 266.1793 - val_rmse: 14.8143
# Epoch 19/35
# 648/648 [==============================] - 0s 35us/step - loss: 278.6326 - rmse: 15.7620 - val_loss: 214.0887 - val_rmse: 12.9011
# Epoch 20/35
# 648/648 [==============================] - 0s 38us/step - loss: 235.0617 - rmse: 14.2222 - val_loss: 171.8009 - val_rmse: 11.6617
# Epoch 21/35
# 648/648 [==============================] - 0s 48us/step - loss: 188.9637 - rmse: 12.6934 - val_loss: 147.8510 - val_rmse: 10.5291
# Epoch 22/35
# 648/648 [==============================] - 0s 55us/step - loss: 154.8858 - rmse: 11.3056 - val_loss: 115.3118 - val_rmse: 8.9471
# Epoch 23/35
# 648/648 [==============================] - 0s 43us/step - loss: 122.9432 - rmse: 9.7943 - val_loss: 79.1487 - val_rmse: 7.1010
# Epoch 24/35
# 648/648 [==============================] - 0s 37us/step - loss: 97.4285 - rmse: 8.6293 - val_loss: 69.3310 - val_rmse: 6.6730
# Epoch 25/35
# 648/648 [==============================] - 0s 39us/step - loss: 73.7697 - rmse: 7.4943 - val_loss: 62.4180 - val_rmse: 6.1376
# Epoch 26/35
# 648/648 [==============================] - 0s 35us/step - loss: 61.3942 - rmse: 6.5941 - val_loss: 40.3252 - val_rmse: 5.0719
# Epoch 27/35
# 648/648 [==============================] - 0s 40us/step - loss: 51.7999 - rmse: 5.8387 - val_loss: 41.2770 - val_rmse: 5.1231
# Epoch 28/35
# 648/648 [==============================] - 0s 40us/step - loss: 40.4442 - rmse: 5.1952 - val_loss: 33.0377 - val_rmse: 4.5580
# Epoch 29/35
# 648/648 [==============================] - 0s 37us/step - loss: 35.1509 - rmse: 4.6934 - val_loss: 31.4439 - val_rmse: 4.4342
# Epoch 30/35
# 648/648 [==============================] - 0s 36us/step - loss: 38.0532 - rmse: 4.9281 - val_loss: 31.2748 - val_rmse: 4.5258
# Epoch 31/35
# 648/648 [==============================] - 0s 39us/step - loss: 24.1980 - rmse: 3.8930 - val_loss: 35.0398 - val_rmse: 4.5463
# Epoch 32/35
# 648/648 [==============================] - 0s 37us/step - loss: 32.5428 - rmse: 4.4124 - val_loss: 32.4894 - val_rmse: 4.5983
# Epoch 33/35
# 648/648 [==============================] - 0s 39us/step - loss: 23.5698 - rmse: 3.7505 - val_loss: 29.8681 - val_rmse: 4.2270
# Epoch 34/35
# 648/648 [==============================] - 0s 48us/step - loss: 21.0290 - rmse: 3.5587 - val_loss: 27.2801 - val_rmse: 3.9977
# Epoch 35/35
# 648/648 [==============================] - 0s 45us/step - loss: 24.2259 - rmse: 3.7941 - val_loss: 26.5839 - val_rmse: 4.0370

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 64)                576
# _________________________________________________________________
# dense_37 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32)                128
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 2,817
# Trainable params: 2,753
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# ## __4 - Conclusion__

# %%
y_predict = model.predict(x_test)

# %%
r2_score(y_test,y_predict)
# Out:
# 0.9090967609830533

# %%
plt.plot(history.history['rmse'])
plt.plot(history.history['val_rmse'])
plt.title('Root Mean Squared Error')
plt.ylabel('rmse')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('4.png')
plt.show()

# %% [markdown]
# ### The model has an acceptable score
